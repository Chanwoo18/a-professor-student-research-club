# %%
from google.colab import drive

# %%
import os

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd drive/MyDrive/YOLOv7_Custom/yolov7-custom
# Out:
# /content/drive/MyDrive/YOLOv7_Custom/yolov7-custom

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7x.pt

# %%
# !python train.py --device 0 --batch-size 16 --epochs 100 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7x-custom.yaml --weights yolov7x.pt --name yolov7x-custom

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/YOLOv7_Custom/yolov7-custom'

# %%
path = './data/val/images'
os.listdir(path)
# Out:
# ['jack sparrow_72.jpeg',
#  'jack sparrow_73.jpeg',
#  'jack sparrow_74.jpeg',
#  'jack sparrow_75.jpeg',
#  'jack sparrow_76.jpeg',
#  'jack sparrow_80.png',
#  'jack sparrow_81.jpeg',
#  'jack sparrow_82.jpeg',
#  'jack sparrow_83.jpeg',
#  'jack sparrow_84.jpeg',
#  'jack sparrow_85.jpeg',
#  'jack sparrow_86.jpeg',
#  'jack sparrow_87.png',
#  'jack sparrow_88.png',
#  'jack sparrow_89.jpeg']

# %%
# !python detect.py --weights runs/train/yolov7x-custom2/weights/best.pt --conf 0.5 --img-size 640 --source tset.jpeg --no-trace
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=True, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='tset.jpeg', update=False, view_img=False, weights=['runs/train/yolov7x-custom2/weights/best.pt'])
# YOLOR 🚀 2023-1-1 torch 1.13.0+cu116 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# IDetect.fuse
# Model Summary: 362 layers, 70782444 parameters, 0 gradients
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1 jack sparrow, Done. (28.0ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs/detect/exp4/tset.jpeg
# Done. (1.073s)

# %%
# !python detect.py --weights runs/train/yolov7x-custom2/weights/best.pt --conf 0.5 --img-size 640 --source test_movie.mp4 --no-trace

# %%
path
# Out:
# './data/val/images'
